# %%
import json
import os

# %%
merge_genre = []
with open('animedataforproject_97.json') as json_file:
    data = json.load(json_file)
    for p in data:
        x = p["Genres"].split(',')
        
        merge_genre = list(set().union(merge_genre,x))
        print(merge_genre)
# Out:
# ['Adventure', 'Military', 'Fantasy', 'Magic', 'Shounen', 'Action', 'Comedy', 'Drama']
# ['Adventure', 'Thriller', 'Fantasy', 'Military', 'Magic', 'Shounen', 'Action', 'Comedy', 'Drama', 'Sci-Fi']
# ['Adventure', 'Thriller', 'Parody', 'Military', 'Fantasy', 'Magic', 'Shounen', 'Action', 'Comedy', 'Historical', 'Drama', 'Sci-Fi', 'Samurai']
# ['Adventure', 'Thriller', 'Parody', 'Fantasy', 'Military', 'Magic', 'Shounen', 'Action', 'Comedy', 'Historical', 'Space', 'Drama', 'Sci-Fi', 'Samurai']
# ['Mystery', 'Adventure', 'Seinen', 'Thriller', 'Parody', 'Military', 'Fantasy', 'Magic', 'Shounen', 'Slice of Life', 'Supernatural', 'Action', 'Comedy', 'Historical', 'Space', 'Drama', 'Sci-Fi', 'Samurai']
# ['Supernatural', 'Action', 'Comedy', 'Seinen', 'Military', 'Fantasy', 'Magic', 'Historical', 'Sci-Fi', 'Mystery', 'Adventure', 'Thriller', 'Shounen', 'Slice of Life', 'Space', 'Drama', 'Parody', 'Police', 'Psychological', 'Samurai']
# ...

# %%
print(merge_genre)
# Out:
# ['Josei', 'Vampire', 'Supernatural', 'Shoujo', 'Action', 'Comedy', 'Sports', 'Seinen', 'Military', 'Fantasy', 'Magic', 'Dementia', 'Harem', 'Mecha', 'Historical', 'Sci-Fi', 'Shounen Ai', 'Mystery', 'Adventure', 'Thriller', 'Shounen', 'Slice of Life', 'Martial Arts', 'Space', 'Horror', 'Drama', 'Demons', 'Game', 'Parody', 'Police', 'Psychological', 'Super Power', 'School', 'Romance', 'Music', 'Samurai']
